# %% [markdown]
# <a href="https://colab.research.google.com/github/beyzakulakac/beyzakulakac/blob/main/Copy_of_staj_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STAJ 1. PROJE

# %% [markdown]
# -Kodların içerisinde kullanılacak fonksiyonların yazılı olduğu kütüphaneler çağırıldı.

# %%
# !pip install pandas matplotlib
import tensorflow as tf
import numpy as np
import pandas as pd
import keras
from keras import layers
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
import os

# %% [markdown]
# -Pandas kütüphanesi ile .csv formatındaki dosya okundu. Artık dosya üzerinde yapılacak tüm işlemler "irs" değişkeni referans alınarak yapılacak. "del" fonksiyonu ile irs dosyasından "unnamed :0" ile gösterilen sütun silindi çünkü o sütun yerinde "id" yazılı sütun vardı ve sadece gözlem sonucu verilerin olduğu satırlara ait numaralardı. Eğitim için bu sütuna ihtiyaç yok. Model eğitildikten sonra bir çiçeğe ait petal genişliği verildiğinde hangi tür olduğunu tahmin etmesinin kaçıncı satırla bir alakası olmadığından bu sütun silindi aksi halde modelin doğruluğu bakımından sıkıntı çıkarabilirdi. "irs.head" fonksiyonu default olarak ilk 5 satırı gösterdi istenirse parantez içine 10 yazarak 10 satır da gösterilebilir.

# %%
irs = pd.read_csv('Iris.csv')
del irs["Unnamed: 0"]
irs.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# -Bu aşamada verisetinin yapısı hakkında bazı kavramları bilmek gerekiyor, bu kavramları açıklayarak başlayacağım. İris veriseti özelinde düşünecek olursak modelin tahmin yaparken baz aldığı özellikler bir çiçeğin farklı 2 yaprağının genişliği ve uzunluğu. İşte bu tahmin yapılırken gözden geçirilen özelliklere "features", tahmin sonucu ulaşılacak sonuca da "target" deniliyor. Modele features değişkenlerini ve target değişkenini tanımlamak gerkeiyor. Aşağıda yer alan kod bloğunun ilk iki satırında bu yapılıyor.
#
# Kullanılacak algoritmanın anlayacaği dilden olması adına kategorileştirme denilen "label encoder" ve "one hot encoder" işlemlerinin uygulanması önemli. Bunlardan hangisinin kullanılacağı konusunda 2 den fazla kategori olması halinde one hot encoder; 2 kategori olması halinde de label encoder kullanmak daha mantıklı çünkü label encoder 2 den fazla değişkeni 0,1,2,3... diye kategorilerken one-hot encoder değişkenleri, özellikleri sağlayıp sağlamamasına göre 0(sağlamıyor) veya 1(sağlıyor) şeklinde matris oluşturuyor. Özetle encoderlar algoritmanın anlayabilmesi için verileri sayısal bir şekilde ifade ediyor.
#
# Modelin daha doğru sonuç vermesi için eğitelecek veriyi "test", "train" ve "valindation" olarak ayırmak gerekiyor. "train" klasöründeki veriler eğitim aşamasından geçerken "test" klasöründeki veriler eğitimin sonucunu görmek için test ediliyor ve "validation" klasöründeki veriler de doğrulama için kullanılıyor.

# %%
x = irs[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm' ,'PetalWidthCm']]
y = irs['Species']
class_names = irs['Species']
ohe = OneHotEncoder()
y = ohe.fit_transform(y.values.reshape(-1,1))
scaler = preprocessing.StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0) #test_size parametresi test olarak kullanacağımız verilerin yüzdesini belirtir. %20 sinin test olacağını belirleiyoruz otomatik olarak %80 train oldu.
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# -Yazımın geri kalanında ödevle ilgili nelerin uyuşmadığından bahsediyorum.
#
#
# ÖDEVDE İSTENİLEN:
#
# Veri Ön İşleme:
#    - Veri setini indirdikten sonra, Keras Image Generator fonksiyonunu kullanarak aşağıda belirtilen ön işleme adımlarını uygulayın:
#      - Rastgele Parlaklık (Random Brightness)
#      - Rastgele Döndürme (Random Rotation)
#      - Görüntü Normalizasyonu (Image Normalization)

# %% [markdown]
# -Yukarıda yazılan isterler aslında birer görüntü işleme adımları. İris verisetinin girdileri genişlik ve uzunluk bilgisi yani sayısal değerler. Bu değerler göz önünde bulundurularak istenilen parlaklık, açı gibi preprocess işlemleri gerçekleştirilemiyor. Bu işlemleri gerçleştirebilmek için kullanılacak verilen birer görüntü olması gerekirdi.
#
# -Aynı zamanda modeli GoogleNet ile eğitmem istendi ancak GoogleNet, ImageNet veritabanı kullanılarak oluşturulmuş bir "image classification" modeli. Bu durumda elimdeki sayısal verileri googlenet modeli ile kullanamıyorum.
